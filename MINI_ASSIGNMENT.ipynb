# %% [markdown]
# # **Mini assignment**

# %% [markdown]
# # Create a DNA string of 10,000 characters and count the following A,T,G,C all combination of two characters

# %%
import random as rn
R = [rn.choice(['A','T','G','C']) for i in range(10000)]
print(R)
# Out:
# ['G', 'C', 'A', 'A', 'C', 'A', 'G', 'G', 'A', 'T', 'G', 'C', 'G', 'G', 'A', 'T', 'A', 'A', 'C', 'C', 'T', 'A', 'A', 'C', 'G', 'A', 'C', 'T', 'G', 'G', 'A', 'G', 'A', 'C', 'A', 'T', 'T', 'C', 'T', 'A', 'A', 'C', 'C', 'G', 'C', 'C', 'G', 'G', 'G', 'C', 'C', 'T', 'C', 'C', 'T', 'A', 'T', 'T', 'A', 'G', 'G', 'T', 'C', 'C', 'T', 'T', 'C', 'C', 'A', 'C', 'A', 'A', 'A', 'C', 'C', 'C', 'T', 'C', 'T', 'A', 'T', 'G', 'G', 'A', 'C', 'G', 'T', 'A', 'G', 'T', 'T', 'C', 'C', 'A', 'G', 'C', 'T', 'T', 'A', 'C', 'C', 'G', 'T', 'C', 'A', 'C', 'G', 'A', 'T', 'A', 'T', 'A', 'C', 'G', 'C', 'T', 'T', 'A', 'G', 'G', 'A', 'G', 'G', 'A', 'G', 'A', 'T', 'C', 'G', 'C', 'G', 'C', 'G', 'G', 'A', 'G', 'T', 'A', 'G', 'C', 'A', 'A', 'C', 'C', 'T', 'C', 'C', 'A', 'C', 'G', 'T', 'G', 'G', 'G', 'G', 'A', 'C', 'C', 'C', 'C', 'G', 'C', 'G', 'T', 'G', 'T', 'G', 'G', 'T', 'C', 'G', 'C', 'G', 'T', 'G', 'G', 'C', 'T', 'C', 'G', 'C', 'A', 'T', 'G', 'A', 'G', 'C', 'A', 'A', 'A', 'G', 'T', 'A', 'C', 'T', 'A', 'C', 'C', 'A', 'T
# ...

# %%
DNA = '' .join(R)
DNA
# Out:
# '...'

# %%
DNA.count("A"),DNA.count("T"),DNA.count("C"),DNA.count("G")
# Out:
# (2474, 2481, 2553, 2492)

# %%
DNA.count("AT"),DNA.count("TA")
# Out:
# (585, 621)

# %%
DNA.count("AA")
# Out:
# 513

# %%
DNA.count('GG'),DNA.count('TT'),DNA.count('CC'),DNA.count('AA')
# Out:
# (496, 490, 540, 513)

# %%
DNA.count('GC'),DNA.count('CG'),DNA.count('TC'),DNA.count('CT')
# Out:
# (645, 626, 600, 634)

# %%
DNA.count('TG'),DNA.count('GT'),DNA.count('AG'),DNA.count('GA')
# Out:
# (635, 638, 610, 589)

# %%
DNA.count('AC'),DNA.count('CA'),DNA.count('TG'),DNA.count('GC'),
# Out:
# (629, 614, 635, 645)

# %%
DNA.count('ATG'),DNA.count('AGT'),DNA.count('AAG'),DNA.count('AGA'),
# Out:
# (165, 158, 157, 128)

# %%
DNA.count('TAG'),DNA.count('GAT'),DNA.count('AGC'),DNA.count('GTA'),
# Out:
# (145, 147, 169, 171)

# %%
DNA.count('TCG'),DNA.count('CGT'),DNA.count('AGC'),DNA.count('GTA'),
# Out:
# (142, 164, 169, 171)

# %%
DNA.count('TGC'),DNA.count('GTC'),DNA.count('ACG'),DNA.count('CGA')
# Out:
# (159, 141, 164, 145)
